# %% [markdown]
# # Pandas II - Data Cleaning
#
# _Aug 5, 2020_
#
# Agenda today:
# - Introduction to lambda function
# - Introduction to data cleaning in pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Part I. Lambda function
# lambda functions are known as anonymous functions in Python. It allows you to write one-line functions that are used together with `map()`, `filter()`.
#
# Syntax of lambda function: `lambda arguments:expressions`.

# %%
# lambda function with one argument
func_1 = (lambda x:x+10)
func_1(10)
# Out:
# 20

# %%
# lambda function with multiple arguments
func_2 = lambda x, y, z: x+y+z if z + y > x else x-y+z
func_2(10,12,10)
# Out:
# 32

# %%
# exercise: turn the below function into a lambda function
def count_zeros(li):
    """
    return a count of how many zeros are in a list
    """
    count = sum(x == 0 for x in li)
    return count

# %%
count_zeros([1,2,4,0])
# Out:
# 1

# %%
#map(function, collection)
#filter(function, collection)# your answer here ----- returns all the elements that are truthy

# %% [markdown]
# ## Part II. Data Cleaning in Pandas
# You might wonder what the usage of lambda functions are - they are incredibly useful when applied to data cleaning in Pandas. You can apply it to columns or the entire dataframe to get results you need. For example, you might want to convert a column with $USD to Euros, or temperature expressed in Celsius to Fehrenheit. You will learn three new functions:
#
# - `Apply()` - on both series and dataframe
#
# - `Applymap()` - only on dataframes
#
# - `Map()` - only on series

# %%
# import the dataframe 
df = pd.read_csv('auto-mpg.csv')

# %%
# examine the first few rows of it 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
# check the datatypes of the df
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
# check whether you have missing values

# %%
# creating new columns - broadcasting 
df['new_col'] = 'Yes' #<=== object in pd vs string in phython try not to iterate here - itero
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name new_col
# 0       1  chevrolet chevelle malibu     Yes
# 1       1          buick skylark 320     Yes
# 2       1         plymouth satellite     Yes
# 3       1              amc rebel sst     Yes
# 4       1                ford torino     Yes

# %%
# check the dataframe

# %%
# time to use lambda and apply! with apply, applymap, and map, you never need to "iterate through the rows"

# create a function that takes in the weight as lbs, and return weight in tons 

# 1 lb = 0.0005

df['weight_in_ton'] = df['weight'].apply(lambda x:x*0.005) # applied a function to a column - specify where you are applying the function to.

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name new_col  weight_in_ton
# 0       1  chevrolet chevelle malibu     Yes         17.520
# 1       1          buick skylark 320     Yes         18.465
# 2       1         plymouth satellite     Yes         17.180
# 3       1              amc rebel sst     Yes         17.165
# 4       1                ford torino     Yes         17.245

# %%
# exercise - create a new column called "years old", which determines how old a car is 

df['years_old'] = df['model year'].apply(lambda x:2020 - (1900 + x))
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name new_col  weight_in_ton  years_old
# 0       1  chevrolet chevelle malibu     Yes         17.520         50
# 1       1          buick skylark 320     Yes         18.465         50
# 2       1         plymouth satellite     Yes         17.180         50
# 3       1              amc rebel sst     Yes         17.165         50
# 4       1                ford torino     Yes         17.245         50

# %% [markdown]
# ### Data Cleaning - level up with the adult dataset

# %% [markdown]
# Dataset documentation:
# - age: continuous.
# - workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# - fnlwgt: continuous.
# - education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# - education-num: continuous.
# - marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# - occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# - relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# - race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# - sex: Female, Male.
# - capital-gain: continuous.
# - capital-loss: continuous.
# - hours-per-week: continuous.
# - native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data'
adults = pd.read_csv(url, header = None) #<--- usecols = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital_status', 'occupation', 'relationship', 'race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country']

# %%
adults
# Out:
#        0                  1       2            3   4                    5   \
# 0      39          State-gov   77516    Bachelors  13        Never-married
# 1      50   Self-emp-not-inc   83311    Bachelors  13   Married-civ-spouse
# 2      38            Private  215646      HS-grad   9             Divorced
# 3      53            Private  234721         11th   7   Married-civ-spouse
# 4      28            Private  338409    Bachelors  13   Married-civ-spouse
# ...    ..                ...     ...          ...  ..                  ...
# 32556  27            Private  257302   Assoc-acdm  12   Married-civ-spouse
# 32557  40            Private  154374      HS-grad   9   Married-civ-spouse
# 32558  58            Private  151910      HS-grad   9              Widowed
# 32559  22            Private  201490      HS-grad   9        Never-married
# 32560  52       Self-emp-inc  287927      HS-grad   9   Married-civ-spouse
#
#                        6               7       8        9      10  11  12  \
# 0            Adm-clerical   Not-in-family   White     Male   2174   0  40
# 1         Exec-managerial         Husband   White     Male      0   0  13
# 2       Handlers-cleaners   Not-in-family   White     Male      0   0  40
# 3       Handlers-cleaners         Husband   Black     Male      0   0  40
# 4          Prof-specialty            Wife   Black   Female      0   0  40
# ...                   ...             ...     ...      ...    ...  ..  ..
# 32556        Tech-support            Wife   White   Female      0   0  38
# 32557   Machine-op-inspct         Husband   White     Male      0   0  40
# 32558        Adm-clerical       Unmarried   White   Female      0   0  40
# 32559        Adm-clerical       Own-child   White     Male      0   0  20
# 32560     Exec-managerial            Wife   White   Female  15024   0  40
#
#                    13      14
# 0       United-States   <=50K
# 1       United-States   <=50K
# 2       United-States   <=50K
# 3       United-States   <=50K
# 4                Cuba   <=50K
# ...               ...     ...
# 32556   United-States   <=50K
# 32557   United-States    >50K
# 32558   United-States   <=50K
# 32559   United-States   <=50K
# 32560   United-States    >50K
#
# [32561 rows x 15 columns]

# %%
# Check the first few rows 
adults.head()
# Out:
#    0                  1       2           3   4                    5   \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7       8        9     10  11  12  \
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#                13      14
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# 3   United-States   <=50K
# 4            Cuba   <=50K

# %%
# add the columns to dataset
columns = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital_status', 'occupation', 'relationship', 'race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'income']

# %%
adults.columns = columns

# %%
# check the info of dataset
adults.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
adults.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
adults.isnull().sum().any()#<=------- check if there are any missing values perform some queries - find the total number of females who has bachelors degree
# Out:
# False

# %%
#adults['sex'] = adults.sex.replace(' ' , None)
#adults['education'] = adults.education.replace(' ' , None)
#adults = adults.applymap(lambda x: x.strip() if type(x)==str else x)

adults.replace(' ','',inplace = True, regex=True)
#adults.strip[adults[' ','sex']

adults.sex.value_counts()
# Out:
# Male      21790
# Female    10771
# Name: sex, dtype: int64

# %%
adults[(adults.sex == 'Female') & (adults.education == 'Bachelors')]
# Out:
#        age  workclass  fnlwgt  education  education-num      marital_status  \
# 4       28    Private  338409  Bachelors             13  Married-civ-spouse
# 12      23    Private  122272  Bachelors             13       Never-married
# 71      31    Private  309974  Bachelors             13           Separated
# 125     47    Private  287828  Bachelors             13  Married-civ-spouse
# 152     33    Private  163003  Bachelors             13       Never-married
# ...    ...        ...     ...        ...            ...                 ...
# 32511   25  Local-gov  514716  Bachelors             13       Never-married
# 32530   35          ?  320084  Bachelors             13  Married-civ-spouse
# 32531   30          ?   33811  Bachelors             13       Never-married
# 32536   34    Private  160216  Bachelors             13       Never-married
# 32538   38    Private  139180  Bachelors             13            Divorced
#
#             occupation    relationship                race     sex  \
# 4       Prof-specialty            Wife               Black  Female
# 12        Adm-clerical       Own-child               White  Female
# 71               Sales       Own-child               Black  Female
# 125    Exec-managerial            Wife               White  Female
# 152    Exec-managerial  Other-relative  Asian-Pac-Islander  Female
# ...                ...             ...                 ...     ...
# 32511     Adm-clerical       Own-child               Black  Female
# 32530                ?            Wife               White  Female
# 32531                ?   Not-in-family  Asian-Pac-Islander  Female
# 32536  Exec-managerial   Not-in-family               White  Female
# 32538   Prof-specialty       Unmarried               Black  Female
#
#        capital_gain  capital_loss  hours_per_week native_country income
# 4                 0             0              40           Cuba  <=50K
# 12                0             0              30  United-States  <=50K
# 71                0             0              40  United-States  <=50K
# 125               0             0              40  United-States   >50K
# 152               0             0              40    Philippines  <=50K
# ...             ...           ...             ...            ...    ...
# 32511             0             0              40  United-States  <=50K
# 32530             0             0              55  United-States   >50K
# 32531             0             0              99  United-States  <=50K
# 32536             0             0              55  United-States   >50K
# 32538         15020             0              45  United-States   >50K
#
# [1619 rows x 15 columns]

# %%
adults = adults.apply(lambda x:x.str.strip() if type (x) == str else x)

# %%
# seems like we have data anolmaly, find out what that is and fix it 

# hint - tons of entries contain white space, remove it!

# %%
# create a column called income_binary, 1 if >50k and 0 otherwise

# %%
# get some descriptive statistics of the income distribution
