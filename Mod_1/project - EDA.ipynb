# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
import matplotlib.pyplot as plt

bom_movie_gross = pd.read_csv('/Users/jefelito/Data Science - Course Material/module01/dsc-mod-1-project-v2-1-nyc01-dtsc-ft-080320/zippedData/bom.movie_gross.csv.gz', delimiter = ',', index_col = ['title', 'studio', 'domestic_gross', 'foreign_gross', 'year'])
df_1 = bom_movie_gross
print(df_1.columns)
df_1
# Out:
# Index([], dtype='object')
# Empty DataFrame
# Columns: []
# ...

# %%
grouped_df = df_1.groupby(['studio', 'year'])

# %%
df_12 = df_1.dropna(axis = 0, inplace=False)
df_12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2007 entries, 0 to 3353
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           2007 non-null   object
#  1   studio          2007 non-null   object
#  2   domestic_gross  2007 non-null   float64
#  3   foreign_gross   2007 non-null   object
#  4   year            2007 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 94.1+ KB

# %%
df_1.dropna(inplace = True)
df_1.dropna(axis = 1)
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2007 entries, 0 to 3353
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           2007 non-null   object
#  1   studio          2007 non-null   object
#  2   domestic_gross  2007 non-null   float64
#  3   foreign_gross   2007 non-null   object
#  4   year            2007 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 94.1+ KB

# %%
df_1.head(15)
# Out:
#                                                 title studio  domestic_gross  \
# 0                                         Toy Story 3     BV     415000000.0
# 1                          Alice in Wonderland (2010)     BV     334200000.0
# 2         Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                           Inception     WB     292600000.0
# 4                                 Shrek Forever After   P/DW     238700000.0
# 5                          The Twilight Saga: Eclipse   Sum.     300500000.0
# 6                                          Iron Man 2   Par.     312400000.0
# 7                                             Tangled     BV     200800000.0
# 8                                       Despicable Me   Uni.     251500000.0
# 9                            How to Train Your Dragon   P/DW     217600000.0
# 10                         Clash of the Titans (2010)     WB     163200000.0
# ...

# %%
# df_23 = df_12.sort_values(by=['studio']).groupby(['studio']).max()
# df_23.info()
df_23.groupby([])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 172 entries, 3D to Zeit.
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           172 non-null    object
#  1   domestic_gross  172 non-null    float64
#  2   foreign_gross   172 non-null    object
#  3   year            172 non-null    int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.7+ KB

# %%
df_23['foreign_gross'] = df_23['foreign_gross'].astype(float)
print(df_23['foreign_gross'].dtype)
# Out:
# float64

# %%
df_23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 172 entries, 3D to Zeit.
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           172 non-null    object
#  1   domestic_gross  172 non-null    float64
#  2   foreign_gross   172 non-null    float64
#  3   year            172 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 6.7+ KB

# %%
df_23.describe()
# Out:
#        domestic_gross  foreign_gross         year
# count    1.720000e+02   1.720000e+02   172.000000
# mean     4.011014e+07   3.038172e+07  2014.534884
# std      1.175031e+08   9.293706e+07     2.997846
# min      8.000000e+02   3.100000e+03  2010.000000
# 25%      1.610000e+05   5.477500e+05  2012.000000
# 50%      1.450000e+06   5.850000e+06  2015.000000
# 75%      1.527500e+07   1.840000e+07  2018.000000
# max      9.367000e+08   8.676000e+08  2018.000000

# %%
df_12['studio'].value_counts()
# Out:
# Uni.            144
# Fox             134
# WB              130
# Sony            105
# BV              104
#                ...
# Greenwich         1
# Darin Southa      1
# MPFT              1
# NYer              1
# DR                1
# Name: studio, Length: 172, dtype: int64
